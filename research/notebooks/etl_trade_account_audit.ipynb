# %%
"""ETL account audit — headless validation only (no charts)."""
from pathlib import Path

import pandas as pd

from forge.promotion import PromotionRecord, passes_gate

# Example: assert panel load + promotion gate (replace with real ETL paths)
DATA = Path("../../forge/data")
assert DATA.exists(), "forge/data must exist"
print("lab mode: tables/metrics only · production code in forge/")

# %%
# Reconcile fills vs targets (stub — wire to forge.execution.state when ETL exists)
sample = PromotionRecord(
    model_id="stub",
    git_commit="local",
    dvc_hash="none",
    oos_sharpe=0.5,
    max_drawdown=0.1,
    turnover=1.0,
)
print("passes_gate:", passes_gate(sample))
# Out:
# /home/opc/sandbox-kernel

# %%
pd.DataFrame([{"check": "account_audit", "status": "stub"}])
# Out:
# hello world
